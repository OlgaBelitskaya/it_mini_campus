# %%
# %%html
# <style>
# @import url('https://fonts.googleapis.com/css?family=Orbitron');
# h1, h2 {color:#3636ff; font-size:110%; font-family:'Orbitron'; text-shadow:5px 5px 5px #aaa;}
# p, a {color:darkblue; font-size:120%; text-shadow:5px 5px 5px #aaa;}
# </style>
# Out:
# <style>
# @import url('https://fonts.googleapis.com/css?family=Orbitron');
# h1, h2 {color:#3636ff; font-size:110%; font-family:'Orbitron'; text-shadow:5px 5px 5px #aaa;}
# p, a {color:darkblue; font-size:120%; text-shadow:5px 5px 5px #aaa;}
# </style>

# %% [markdown]
# <h1>Tabulating Functions with Two Variables</h1>
# Create an algorithm and a program<br/>
# Составить таблицу значений функции двух переменных по заданной формуле. Результаты представить в виде матрицы. <br/>
# Если номер задания четный, то в строке размещать значения функции для одного и того же значения Х, <br/>
# а если номер задания нечетный, то для одного и того же значения Z.

# %%
def create_matrix(f,x,z):
    t=[]; pretty_print(html(latex(f)))
    for zv in z: t+=[[zv]+[f(xv,zv) for xv in x]]
    nt=[['$z$']+['$x_%s=%s$'%(i+1,x[i]) for i in range(len(x))]]
    show(table(nt+t))
    return Matrix(t)
f21(x,z)=(abs(x^z+z^(x+3)))^(1/7)/(sin(x*z)^2+1/4)
X=[1,2,3,4,5]; Z=[1.2,1.3,1.4,1.5,1.6]; create_matrix(f21,X,Z)
plot3d(f21,(x,1,5),(z,1.2,1.6),mesh=True,opacity=.5,adaptive=True).show()
# Out:
# <script type="math/tex">\left( x, z \right) \ {\mapsto} \ \frac{4 \, {\left| x^{z} + z^{x + 3} \right|}^{\frac{1}{7}}}{4 \, \sin\left(x z\right)^{2} + 1}</script>
#   $z$                $x_1=1$            $x_2=2$            $x_3=3$            $x_4=4$            $x_5=5$
#   1.20000000000000   1.04942519951875   1.77082853061078   2.94483628291385   1.09929517665745   4.30436676538821
#   1.30000000000000   1.02902607885137   2.51488493060894   1.89301790489962   1.38945988355915   5.02715303810774
#   1.40000000000000   1.02588895474813   3.71687223190650   1.41563044521808   2.32107359829159   2.31383973015274
#   1.50000000000000   1.03905694706564   5.17840300452623   1.23897070707187   4.83001080331437   1.48145909643405
#   1.60000000000000   1.06865343205290   5.72447526302087   1.25643028214530   6.33092872690671   1.44657368044273
# Graphics3d Object

# %%
def create_matrix2(f,x,z):
    t=[]; pretty_print(html(latex(f)))
    for xv in x: t+=[[xv]+[f(xv,zv) for zv in z]]
    nt=[['$x$']+['$z_%s=%s$'%(i+1,round(z[i],1)) for i in range(len(z))]]
    show(table(nt+t))
    return Matrix(t)
f22(x,z)=(3/7+arctan((x+z)/(x*z)))/(ln(abs(z))+(x*z)^2)
X=[1,2,3,5,8]; Z=[.2,.4,.6,.8,1.]; create_matrix2(f22,X,Z)
plot3d(f22,(x,1,8),(z,.2,1),mesh=True,opacity=.5,adaptive=True).show()
# Out:
# <script type="math/tex">\left( x, z \right) \ {\mapsto} \ \frac{7 \, \arctan\left(\frac{x + z}{x z}\right) + 3}{7 \, {\left(x^{2} z^{2} + \log\left({\left| z \right|}\right)\right)}}</script>
#   $x$   $z_1=0.2$           $z_2=0.4$           $z_3=0.6$            $z_4=0.8$            $z_5=1.0$
#   1     -1.16871082533424   -2.27566995578044   -10.8774427324178    3.79301659065588     1.53572014636552
#   2     -1.25532403972949   -6.07192716740786   1.68640033547498     0.633424291831128    0.352841287954689
#   3     -1.45186870617415   3.16984105867183    0.562705028941632    0.259362240502950    0.150651849619227
#   5     -2.96893158520600   0.533338898175360   0.177586006902878    0.0884598542496812   0.0521851791667849
#   8     1.90063018537828    0.175401093258822   0.0661496441039603   0.0336445074174374   0.0198863346044469
# Graphics3d Object
